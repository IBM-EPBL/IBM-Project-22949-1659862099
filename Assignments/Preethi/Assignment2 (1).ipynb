# %%
import pandas as pd
import numpy as np
import sklearn as sk

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/Churn_Modelling.csv")

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data.isnull().sum() #handle missing values
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
#encoding
from sklearn.preprocessing import LabelEncoder

# %%
le= LabelEncoder()

# %%
data['CreditScore']= le.fit_transform(data['CreditScore'])#catagorial to numerical

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          228    France  Female   42
# 1          2    15647311      Hill          217     Spain  Female   41
# 2          3    15619304      Onio          111    France  Female   42
# 3          4    15701354      Boni          308    France  Female   39
# 4          5    15737888  Mitchell          459     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
y= data['EstimatedSalary']
x=data.drop(columns=['EstimatedSalary'],axis=1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
names= x.columns

# %%
scaler=StandardScaler()

# %%
x
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          228    France  Female   42
# 1             2    15647311       Hill          217     Spain  Female   41
# 2             3    15619304       Onio          111    France  Female   42
# 3             4    15701354       Boni          308    France  Female   39
# 4             5    15737888   Mitchell          459     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          380    France    Male   39
# 9996       9997    15569892  Johnstone          125    France    Male   35
# 9997       9998    15584532        Liu          318    France  Female   36
# 9998       9999    15682355  Sabbatini          381   Germany    Male   42
# 9999      10000    15628319     Walker          401    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  Exited
# 0          2       0.00              1          1               1       1
# 1          1   83807.86              1          0               1       0
# 2          8  159660.80              3          1               0       1
# 3          1       0.00              2          0               0       0
# 4          2  125510.82              1          1               1       0
# ...      ...        ...            ...        ...             ...     ...
# 9995       5       0.00              2          1               0       0
# 9996      10   57369.61              1          1               1       0
# 9997       7       0.00              1          0               1       1
# 9998       3   75075.31              2          1               0       1
# 9999       4  130142.79              1          1               0       0
#
# [10000 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 584         585    15803689      Begum          256   Germany  Female   51
# 4762       4763    15756071       Kang          365    France    Male   34
# 654         655    15751710  Ginikanwa          338     Spain    Male   31
# 1079       1080    15748856      Liang          273    France    Male   32
# 2134       2135    15610355     Hunter          322    France    Male   44
# ...         ...         ...        ...          ...       ...     ...  ...
# 9278       9279    15584580  Fyodorova           52    France    Male   35
# 699         700    15736534     Elkins          351   Germany    Male   33
# 156         157    15655007         Li          367    France  Female   33
# 5046       5047    15708289     Graham          402     Spain    Male   25
# 1742       1743    15578603  Alexeieva          193   Germany  Female   54
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  Exited
# 584        1  119741.77              2          0               0       1
# 4762       1  103133.26              1          1               1       0
# 654        8  164870.81              2          1               1       0
# 1079      10  107209.73              1          1               1       0
# 2134       1   63438.91              1          1               0       0
# ...      ...        ...            ...        ...             ...     ...
# 9278       6  161111.45              1          0               0       0
# 699        0  181656.51              1          1               1       0
# 156        7       0.00              2          0               0       0
# 5046       3  100913.57              1          0               0       0
# 1742       1   77354.37              1          0               0       1
#
# [8000 rows x 13 columns]

# %%
x_test
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 1112       1113    15714750     Northey          299    France  Female   42
# 2044       2045    15566494        Fang           96    France    Male   45
# 7514       7515    15715907    Onwubiko          308    France    Male   64
# 2367       2368    15682600          Lo          229   Germany    Male   39
# 7991       7992    15787710    Tikhonov           36     Spain  Female   39
# ...         ...         ...         ...          ...       ...     ...  ...
# 2047       2048    15814536       Conti          158    France    Male   37
# 8582       8583    15637947         Wei          277     Spain    Male   32
# 1493       1494    15686963    Hardiman          289     Spain  Female   30
# 4478       4479    15622443    Marshall          158    France    Male   31
# 5199       5200    15726310  Mordvinova          391     Spain  Female   27
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  Exited
# 1112       3   92578.14              2          0               0       0
# 2044       2       0.00              2          1               0       0
# 7514       9  113109.52              1          1               0       1
# 2367       9  159492.79              1          1               0       1
# 7991       9       0.00              2          1               0       0
# ...      ...        ...            ...        ...             ...     ...
# 2047       2  112541.54              2          0               0       0
# 8582       1  134446.04              1          0               1       0
# 1493       3       0.00              1          1               0       0
# 4478       4       0.00              2          0               1       0
# 5199       3       0.00              2          1               0       0
#
# [2000 rows x 13 columns]

# %%
y_test
# Out:
# 1112     70810.60
# 2044     77475.73
# 7514     27980.80
# 2367     80582.34
# 7991     28368.37
#           ...
# 2047     47432.43
# 8582    111241.37
# 1493    160131.58
# 4478     25684.85
# 5199    143614.01
# Name: EstimatedSalary, Length: 2000, dtype: float64

# %%
y_train
# Out:
# 584      54954.51
# 4762     90059.04
# 654       9567.39
# 1079    112340.20
# 2134     64375.40
#           ...
# 9278     13946.66
# 699     107667.91
# 156      82996.47
# 5046     10579.72
# 1742    138192.98
# Name: EstimatedSalary, Length: 8000, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
x=x.head(10)
x
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          228    France  Female   42
# 1          2    15647311      Hill          217     Spain  Female   41
# 2          3    15619304      Onio          111    France  Female   42
# 3          4    15701354      Boni          308    France  Female   39
# 4          5    15737888  Mitchell          459     Spain  Female   43
# 5          6    15574012       Chu          254     Spain    Male   44
# 6          7    15592531  Bartlett          431    France    Male   50
# 7          8    15656148    Obinna            8   Germany  Female   29
# 8          9    15792365        He          110    France    Male   44
# 9         10    15592389        H?          293    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  Exited
# 0       2       0.00              1          1               1       1
# 1       1   83807.86              1          0               1       0
# 2       8  159660.80              3          1               0       1
# 3       1       0.00              2          0               0       0
# 4       2  125510.82              1          1               1       0
# 5       8  113755.78              2          1               0       1
# 6       7       0.00              2          1               1       0
# 7       4  115046.74              4          1               0       1
# 8       4  142051.07              2          0               1       0
# 9       2  134603.88              1          1               1       0

# %%
plt.scatter(x.Age,x.Balance)
